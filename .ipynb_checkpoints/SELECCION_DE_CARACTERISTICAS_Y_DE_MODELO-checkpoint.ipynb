# %% [markdown]
# En este cuaderno realizaré la selección de las características y la selección del modelo de predicción con las variables transformadas según lo concluido en el análisis exploratorio. Como primer paso importo algunas de las librerías necesarias:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Cargo el dataset de la competición de Kaggle:

# %%
kobe_df = pd.read_csv("data.csv")

# %% [markdown]
# Creo una máscara para seleccionar sólo los datos de entrenamiento (los que usaré para la selección de características). La variable abajo creada (la máscara), indica si los datos de shot_made_flag son nulos (True. Los datos son de test) o no (False. Los datos son de entrenamiento):

# %%
shot_nan = kobe_df['shot_made_flag'].isnull() #variable que indica si los valores son Nans o no Nans.

# %% [markdown]
# ### TRANSFORMACIÓN DE LAS VARIABLES

# %% [markdown]
# Transformamos teniendo en cuenta los resultados del ánálisis exploratorio y ciertas consideraciones para una buena predicción. Primero elimino del dataset aquellas variables que no me van a resultar necesarias:

# %%
kobe_df.drop(['game_event_id', 'game_id', 'lat', 'lon', 'team_id','shot_id', 'team_name', 'game_date'], 
               axis=1, inplace=True)

# %% [markdown]
# Transformo la variable shot_distance de manera que aquellos valores superiores a 45 pies entren dentro de un mismo valor (45), debido a que existen pocos registros superiores a este valor:

# %%
kobe_df['shot_distance'] = kobe_df.apply(lambda row: row['shot_distance']  if row['shot_distance']<45\
                                             else 45, axis=1)

# %% [markdown]
# Creo una nueva variable, donde se refleje  si el equipo de Kobe era visitante (@/0) o residente (vs/1), ya que estos datos parecen ser relevantes según el análisis exploratorio:

# %%
kobe_df['transformed_matchup'] = kobe_df.apply(lambda row: 0 if '@' in row['matchup'] else 1, axis=1 )

# %%
kobe_df = kobe_df.drop('matchup', axis=1) # Borro 'matchup' ya que no me será de más relevancia.

# %% [markdown]
# Transformo la variable action_type. Para ello, primero creo una variable donde aparece la ocurrencia de cada categoría de action_type en el dataset.

# %%
action_count = kobe_df['action_type'].value_counts()

# %% [markdown]
# Posteriormente, modifico la variable para que aparezcan las categorías de action_type con registros en el dataset superiores a 150, mientras que aquellas categorías con menos de 150 registros serán sustituidas por una categoría global llamada 'other'. Utilizo en el proceso la variable 'action_counts', antes definida:

# %%
kobe_df['action_type'] = kobe_df.apply(lambda row:row['action_type'] if action_count[row['action_type']]>150\
                                             else 'other', axis=1)

# %% [markdown]
# Ya que minutes_remaining se refiere a los últimos 11 minutos del periodo y seconds_remaining al último periodo de este, creo una variable donde se resuma y condense esta información, donde aparezcan los doce minutos del  último periodo:

# %%
kobe_df['time_remaining'] = kobe_df.apply(lambda row: row['minutes_remaining'] * 60 + row['seconds_remaining'], 
                                          axis=1)

# %% [markdown]
# En el análisis exploratorio vimos que en los últimos segundos de partido el rendimiento de los tiros bajaba de forma muy llamativa. Para visibilizar mejor este cambio creo la siguiente variable:

# %%
kobe_df['last_moments'] = kobe_df.apply(lambda row: 1 if row['time_remaining'] < 3 else 0, axis=1)

# %% [markdown]
# A continuación  realizaré una codificación ordinal sobre las variables categóricas del dataset, con el fin de poder utilizarlas en los algoritmos que a continuación usaré para la selección de las variables y del modelo. Como indico en el trabajo escrito, esto lo llevaré a cabo con LabelEnconder de scikit learn:

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Este LabelEncoder lo usaré sobre el conjunto de train de la competición, seleccionado mediante la máscara shot_nan, que indica si los valores del dataset para shot_made_flag son nulos o no. El resultado será un nuevo dataset (kobe_select) con las variables categóricas codificadas:

# %%
kobe_train = kobe_df[~shot_nan] #Selecciono aquellos registros que no poseen valores nulos para sus valores de 
                                 # shot_made_flag: los datos del conjunto de entrenamiento.

kobe_select = kobe_train  #Renombro al conjunto de entrenamiento como kobe_select.

le = LabelEncoder() #Variable con el LabelEncoder.

categorical_features = [ 'action_type','combined_shot_type', 'period', 'season','playoffs','transformed_matchup','shot_type',
                         'shot_zone_area', 'shot_zone_basic', 'shot_zone_range','opponent'] # Lista con las 
                                                                                            # variables categóricas.


#Utilizo la lista de las variables categóricas para transformar cada una de ellas en un bucle con LabelEncoder(le):

for i in categorical_features: 
    
    kobe_select[i] = le.fit_transform(kobe_select[i])

# %% [markdown]
# ### SELECCIÓN DE CARACTERÍSTICAS

# %% [markdown]
# Realizadas las transformaciones, procedo a seleccionar las características más relevantes (en base al dataset kobe_select), que más información aportan al modelo y por tanto permitirán una mejor predicción.

# %% [markdown]
# La selección se llevará a cabo a través de RFE. Sólo seleccionaremos las variables que tengan puesto 1 en el ranking.

# %%
from xgboost import XGBClassifier
from sklearn.feature_selection import RFE
xgb = XGBClassifier() # El estimador utilizado será XGBOOST.

# Establezco 'x' e 'y' para llevar a cabo la selección:

x = kobe_select.drop('shot_made_flag', axis=1)
y = kobe_select['shot_made_flag']

# Procedo a ejecutar la selección:

rfe = RFE(xgb, step=1)
rfe = rfe.fit(x,y)

# %% [markdown]
# Creo un dataset con las variables a analizar y el resultado del ranking para mostrar los resultados de manera interpretable:

# %%
ranking=pd.DataFrame({'Attributes': x.columns ,
              'Ranking': rfe.ranking_})

# %%
ranking # Aquí los resultados.
# Out:
#              Attributes  Ranking
# 0           action_type        1
# 1    combined_shot_type        1
# 2                 loc_x        2
# 3                 loc_y        1
# 4     minutes_remaining        9
# 5                period        8
# 6              playoffs        3
# 7                season        1
# 8     seconds_remaining        7
# 9         shot_distance        1
# 10            shot_type        6
# 11       shot_zone_area        1
# 12      shot_zone_basic        5
# 13      shot_zone_range        1
# 14             opponent        4
# 15  transformed_matchup        1
# 16       time_remaining        1
# 17         last_moments       10

# %% [markdown]
# Según el criterio que antes he establecido, las variables seleccionadas son **action_type**, **combined_shot_type**,**loc_y**, **season**, **shot_distance**, **shot_zone_area**,**shot_zone_range**, **transformed_matchup**, **time_remaining**.

# %% [markdown]
# ### SELECCIÓN DEL MODELO

# %% [markdown]
# Con las variables seleccionadas, procedo a seleccionar el mejor modelo para el problema a resolver. Los modelos a comparar serán **Random Forest**, **XGBoost**, **AdaBoost**, **Support Vector Machine**, **KNN** y **Red Neuronal**:

# %% [markdown]
# Creo con la librería keras la red neuronal. Cuatro capas: la capa de entrada de 12 neuronas, la primera capa oculta de 8, la segunda oculta de 6 y la capa de salida de 1:

# %%
from keras.models import Sequential #Import los métodos de keras necesarios.
from keras.layers import Dense
from keras import losses

def neural_model(): #la red neuronal-
    
    model=Sequential()
    model.add(Dense(12, input_dim=9, activation='relu')) # Capa de entrada. Input_dim= 9 porque las variables 
                                                         # seleccionadas son 9.
    model.add(Dense(8, activation='relu')) #Capa oculta.
    model.add(Dense(6, activation='relu')) #Capa oculta.
    model.add(Dense(1, activation='sigmoid')) #Capa de salida.
    
    #Función de pérdida log_loss, optimizador adam y métrica accuracy:
    
    model.compile(loss= losses.binary_crossentropy, optimizer='adam', metrics=['accuracy']) 
    
    return model

# %% [markdown]
# Como el problema es de clasificación y también para poder usar cross validation en la red neuronal uso KerasClassifier (al ser el modelo de otra librería, necesita de un método "adaptador" para poder usar en él métodos de otra librería):

# %%
from keras.wrappers.scikit_learn import KerasClassifier
n_classifier=KerasClassifier(build_fn=neural_model, epochs=150,batch_size=10) # En este KerasClassifier establezco 
                                                                             # el valor de epochs y de batch_size.

# %% [markdown]
# Establezco **x** (x_1. Con las variables seleccionadas) e **y** (y_1. Con la variable respuesta) para los distintos distintos modelos a comparar:

# %%
x_1 = kobe_select[['action_type', 'combined_shot_type','loc_y', 'season', 'shot_distance', 
                   'shot_zone_area','shot_zone_range', 'transformed_matchup', 'time_remaining']]

y_1 = kobe_select['shot_made_flag']

# %% [markdown]
# Establezco un **x** (x_n) e **y** (y_n) aparte para la red neuronal, donde sólo existen los valores y no las etiquetas (nombres de columnas) de estos, pues así es necesario para que la red neuronal pueda procesar los datos:

# %%
x_n = x_1.values

y_n = y_1.values

# %% [markdown]
# Definido y establecido todo lo anterior, creo una lista con los nombres de los modelos y sus clasificadores. Esta lista la usaré durante la comparación de modelos con cross validation:

# %%
# Aquí Llamo ya al KFold que usaré en el cross validation (Kfold establece las divisiones en las que se partirá 
# el conjunto de datos en el proceso de cross validation:

from sklearn.model_selection import KFold 

from sklearn.ensemble import RandomForestClassifier #Clasificador Random Forest.
from sklearn.ensemble import AdaBoostClassifier #Clasificador AdaBoost.
from sklearn.neighbors import KNeighborsClassifier #Clasificador KNN.
from sklearn.svm import SVC #Clasificador Support Vector Machine.

# Como XGBoost pertenece a otra librería ajena a scikit learn, para poder usar cross validation en él, importo su 
# librería de python y su clasificador XGBClassifier (esto es necesario para que XGBoost no de problemas al 
# aplicarle el método de cross validation):

import xgboost 
from xgboost import XGBClassifier # y su clasificador XGBoost

xgb = xgboost.XGBClassifier() # guardo lo anteriormente importado de la librería XGBoost en una variable, de manera
                              # que así pueda usar cross validation en XGBoost. Esta variable la guardaré en la 
                               # lista de modelos como clasificador de XGBoost.

clf = SVC(probability=True) # Para usar el clasificador de Support Vector Machine, es recomendable que le dé a su 
                            # atributo "probability" el valor True. Guardo la selección en una variable. 


modelos = [] #Creo la lista de modelos.

#Y le añado los modelos (tupla:(nombre, método de clasificación)):

modelos.append(('RandomForest', RandomForestClassifier()))
modelos.append(('Adaboost', AdaBoostClassifier()))
modelos.append(('XGBOOST',xgb ))
modelos.append(('KNN', KNeighborsClassifier()))
modelos.append(('SVC', clf))
modelos.append(('Neural Network model', n_classifier))

# %% [markdown]
# Hecho esto, procedo a ejecutar los modelos usando cross validation (para evitar sobreaprendizaje). La métrica usada para realizar la comparación será negativa_log_loss, un equivalente a log_loss (métrica a optimizar en la competición) pero con valores negativos, por lo que el modelo a seleccionar será aquel que maximice la métrica usada (es decir, que dé un negative log loss mayor):

# %%
#Importo cross validation (cross_val_score) desde scikit learn:

from sklearn.model_selection import cross_val_score 

num_folds = 10
score = 'neg_log_loss' #Establezco la métrica con la que compararé los modelos: negative log loss.



results = [] #Lista donde se guardarán los resultados de cada iteración de cross_validation. 
nombres = [] #Lista donde guardo los nombres de los modelos.

neg_loglossdf = [] # lista donde guardo cada uno de los valores de negative log loss emitidos por cross validation. 10 por cada modelo.
                  # Esta lista la usaré después para guardar en un dataframe los resultados desglosados por 
                  # iteración.
modeldf = [] # Lista que usaré en el dataframe antes mencionado. Esta lista está destinada a guardar el nombre del modelo corres-
           # pondiente por cada iteración de cross_val_score, de manera que así sabremos a qué modelo corresponde cada 
           # resultado de neg_log_loss en los resultados de cross_val_score.



#Por cada modelo ejecutamos cross_val_score:

for nombre, modelo in modelos:
    cv = KFold(n_splits=num_folds, random_state=10) # n_splits (número de divisiones)=10, establecemos una semilla 
                                                    # fija (random_state=10)
    if nombre=='Neural Network model': #Si el modelo es la red neuronal
        cv_results=cross_val_score(modelo, x_n, y_n, cv=cv, scoring='neg_log_loss') #Uso x_n e y_n
        results.append(cv_results) #añado resultados en array por cada modelo a lista results.
        nombres.append(nombre) #añado modelo usado a lista nombres.
        msg = "%s -> media: %f varianza: %f" % (nombre, cv_results.mean(), cv_results.std()) # Imprimo el resultado 
                                                                                             # de cross_val_score 
        print(msg)                                                                           # por cada modelo.
        
        for i in cv_results: # por cada resultado de cada iteración de cross_val_score
            modeldf.append(nombre) # añado el modelo correspondiente a modeldf
            neg_loglossdf.append(i) # y el resultado a neg_loglossdf
        
    
            
    else: # Procedo exactamente igual con el resto de modelos.
        
        cv = KFold(n_splits=num_folds, random_state=10)
        cv_results = cross_val_score(modelo,x_1,y_1 ,      # Pero uso x_1 e y_1.
                                     cv=cv, scoring='neg_log_loss')
        results.append(cv_results)
        nombres.append(nombre)
        msg = "%s -> media: %f varianza: %f" % (nombre, cv_results.mean(), cv_results.std())
        print(msg)
        
        for i in cv_results:
            modeldf.append(nombre)
            neg_loglossdf.append(i)
# Out:
# C:\Users\Luis-MLV\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# RandomForest -> media: -0.673417 varianza: 0.024723
# C:\Users\Luis-MLV\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# Adaboost -> media: -0.688801 varianza: 0.000467
# C:\Users\Luis-MLV\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# XGBOOST -> media: -0.626136 varianza: 0.013309
# C:\Users\Luis-MLV\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# KNN -> media: -1.986807 varianza: 0.116187
# C:\Users\Luis-MLV\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# SVC -> media: -0.668714 varianza: 0.006722
# Epoch 1/150
# C:\Users\Luis-MLV\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# 2313/2313 [==============================] - 1s 433us/step - loss: 1.2532 - accuracy: 0.5502
# Epoch 2/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6863 - accuracy: 0.5577
# Epoch 3/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6855 - accuracy: 0.5589
# Epoch 4/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6854 - accuracy: 0.5610
# Epoch 5/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6828 - accuracy: 0.5673
# Epoch 6/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6822 - accuracy: 0.5693
# Epoch 7/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6784 - accuracy: 0.5801
# Epoch 8/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6602 - accuracy: 0.6177
# Epoch 9/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6465 - accuracy: 0.6426
# Epoch 10/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6454 - accuracy: 0.6410
# Epoch 11/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6428 - accuracy: 0.6447
# Epoch 12/150
# 2313/2313 [==============================] - 1s 459us/step - loss: 0.6423 - accuracy: 0.6477
# Epoch 13/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6419 - accuracy: 0.6475
# Epoch 14/150
# 2313/2313 [==============================] - 1s 470us/step - loss: 0.6414 - accuracy: 0.6477
# Epoch 15/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6421 - accuracy: 0.6468
# Epoch 16/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6405 - accuracy: 0.6498
# Epoch 17/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6399 - accuracy: 0.6479
# Epoch 18/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6391 - accuracy: 0.6495
# Epoch 19/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6390 - accuracy: 0.6487
# Epoch 20/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6365 - accuracy: 0.6520
# Epoch 21/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6343 - accuracy: 0.6511
# Epoch 22/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6336 - accuracy: 0.6505
# Epoch 23/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6332 - accuracy: 0.6509
# Epoch 24/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6333 - accuracy: 0.6512
# Epoch 25/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6327 - accuracy: 0.6512
# Epoch 26/150
# 2313/2313 [==============================] - 1s 534us/step - loss: 0.6322 - accuracy: 0.6532
# Epoch 27/150
# 2313/2313 [==============================] - 1s 532us/step - loss: 0.6326 - accuracy: 0.6517
# Epoch 28/150
# 2313/2313 [==============================] - 1s 467us/step - loss: 0.6312 - accuracy: 0.6537
# Epoch 29/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6308 - accuracy: 0.6535
# Epoch 30/150
# 2313/2313 [==============================] - 1s 528us/step - loss: 0.6301 - accuracy: 0.6528
# Epoch 31/150
# 2313/2313 [==============================] - 1s 498us/step - loss: 0.6299 - accuracy: 0.6565
# Epoch 32/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6290 - accuracy: 0.6544
# Epoch 33/150
# 2313/2313 [==============================] - 1s 465us/step - loss: 0.6299 - accuracy: 0.6542
# Epoch 34/150
# 2313/2313 [==============================] - 1s 500us/step - loss: 0.6282 - accuracy: 0.6564
# Epoch 35/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6283 - accuracy: 0.6578
# Epoch 36/150
# 2313/2313 [==============================] - 1s 476us/step - loss: 0.6284 - accuracy: 0.6578
# Epoch 37/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6266 - accuracy: 0.6600
# Epoch 38/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6270 - accuracy: 0.6588
# Epoch 39/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6271 - accuracy: 0.6565
# Epoch 40/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6262 - accuracy: 0.6578
# Epoch 41/150
# 2313/2313 [==============================] - 1s 469us/step - loss: 0.6257 - accuracy: 0.6616
# Epoch 42/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6257 - accuracy: 0.6593
# Epoch 43/150
# 2313/2313 [==============================] - 1s 425us/step - loss: 0.6251 - accuracy: 0.6594
# Epoch 44/150
# 2313/2313 [==============================] - 1s 457us/step - loss: 0.6246 - accuracy: 0.6624
# Epoch 45/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6234 - accuracy: 0.6636
# Epoch 46/150
# 2313/2313 [==============================] - 1s 462us/step - loss: 0.6238 - accuracy: 0.6638
# Epoch 47/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6226 - accuracy: 0.6629
# Epoch 48/150
# 2313/2313 [==============================] - 1s 426us/step - loss: 0.6235 - accuracy: 0.6632
# Epoch 49/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6237 - accuracy: 0.6616
# Epoch 50/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6218 - accuracy: 0.6651
# Epoch 51/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6222 - accuracy: 0.6652
# Epoch 52/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6214 - accuracy: 0.6656
# Epoch 53/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6216 - accuracy: 0.6643
# Epoch 54/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6203 - accuracy: 0.6651
# Epoch 55/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6212 - accuracy: 0.6654
# Epoch 56/150
# 2313/2313 [==============================] - 1s 517us/step - loss: 0.6229 - accuracy: 0.6628
# Epoch 57/150
# 2313/2313 [==============================] - 1s 481us/step - loss: 0.6201 - accuracy: 0.6636
# Epoch 58/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6199 - accuracy: 0.6676
# Epoch 59/150
# 2313/2313 [==============================] - 1s 425us/step - loss: 0.6197 - accuracy: 0.6668
# Epoch 60/150
# 2313/2313 [==============================] - 1s 486us/step - loss: 0.6201 - accuracy: 0.6665
# Epoch 61/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6189 - accuracy: 0.6674
# Epoch 62/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6196 - accuracy: 0.6650
# Epoch 63/150
# 2313/2313 [==============================] - 1s 426us/step - loss: 0.6193 - accuracy: 0.6658
# Epoch 64/150
# 2313/2313 [==============================] - 1s 426us/step - loss: 0.6179 - accuracy: 0.6690
# Epoch 65/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6183 - accuracy: 0.6677
# Epoch 66/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6187 - accuracy: 0.6665
# Epoch 67/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6185 - accuracy: 0.6660
# Epoch 68/150
# 2313/2313 [==============================] - 1s 465us/step - loss: 0.6178 - accuracy: 0.6687
# Epoch 69/150
# 2313/2313 [==============================] - 1s 465us/step - loss: 0.6197 - accuracy: 0.6659
# Epoch 70/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6174 - accuracy: 0.6681
# Epoch 71/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6180 - accuracy: 0.6665
# Epoch 72/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6172 - accuracy: 0.6671
# Epoch 73/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6175 - accuracy: 0.6687
# Epoch 74/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6183 - accuracy: 0.6658
# Epoch 75/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6167 - accuracy: 0.6685
# Epoch 76/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6164 - accuracy: 0.6688
# Epoch 77/150
# 2313/2313 [==============================] - 1s 425us/step - loss: 0.6161 - accuracy: 0.6693
# Epoch 78/150
# 2313/2313 [==============================] - 1s 426us/step - loss: 0.6180 - accuracy: 0.6648
# Epoch 79/150
# 2313/2313 [==============================] - 1s 426us/step - loss: 0.6182 - accuracy: 0.6666
# Epoch 80/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6174 - accuracy: 0.6672
# Epoch 81/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6156 - accuracy: 0.6706
# Epoch 82/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6170 - accuracy: 0.6680
# Epoch 83/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6168 - accuracy: 0.6692
# Epoch 84/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6188 - accuracy: 0.6644
# Epoch 85/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6150 - accuracy: 0.6700
# Epoch 86/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6152 - accuracy: 0.6695
# Epoch 87/150
# 2313/2313 [==============================] - 1s 467us/step - loss: 0.6168 - accuracy: 0.6685
# Epoch 88/150
# 2313/2313 [==============================] - 1s 458us/step - loss: 0.6166 - accuracy: 0.6689
# Epoch 89/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6159 - accuracy: 0.6686
# Epoch 90/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6141 - accuracy: 0.6714
# Epoch 91/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6155 - accuracy: 0.6691
# Epoch 92/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6138 - accuracy: 0.6706
# Epoch 93/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6150 - accuracy: 0.6705
# Epoch 94/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6148 - accuracy: 0.6699
# Epoch 95/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6145 - accuracy: 0.6701
# Epoch 96/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6153 - accuracy: 0.6700
# Epoch 97/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6155 - accuracy: 0.6697
# Epoch 98/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6144 - accuracy: 0.6693
# Epoch 99/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6154 - accuracy: 0.6682
# Epoch 100/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6147 - accuracy: 0.6716
# Epoch 101/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6162 - accuracy: 0.6688
# Epoch 102/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6146 - accuracy: 0.6699
# Epoch 103/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6145 - accuracy: 0.6702
# Epoch 104/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6146 - accuracy: 0.6706
# Epoch 105/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6149 - accuracy: 0.6706
# Epoch 106/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6147 - accuracy: 0.6675
# Epoch 107/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6142 - accuracy: 0.6692
# Epoch 108/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6157 - accuracy: 0.6689
# Epoch 109/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6148 - accuracy: 0.6700
# Epoch 110/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6138 - accuracy: 0.6708
# Epoch 111/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6136 - accuracy: 0.6720
# Epoch 112/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6145 - accuracy: 0.6700
# Epoch 113/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6138 - accuracy: 0.6715
# Epoch 114/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6137 - accuracy: 0.6727
# Epoch 115/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6138 - accuracy: 0.6707
# Epoch 116/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6138 - accuracy: 0.6711
# Epoch 117/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6134 - accuracy: 0.6696
# Epoch 118/150
# 2313/2313 [==============================] - 1s 481us/step - loss: 0.6132 - accuracy: 0.6712
# Epoch 119/150
# 2313/2313 [==============================] - 1s 468us/step - loss: 0.6133 - accuracy: 0.6709
# Epoch 120/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6144 - accuracy: 0.6693
# Epoch 121/150
# 2313/2313 [==============================] - 1s 440us/step - loss: 0.6134 - accuracy: 0.6705
# Epoch 122/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6135 - accuracy: 0.6697
# Epoch 123/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6127 - accuracy: 0.6724
# Epoch 124/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6142 - accuracy: 0.6690
# Epoch 125/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6132 - accuracy: 0.6713
# Epoch 126/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6146 - accuracy: 0.6692
# Epoch 127/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6125 - accuracy: 0.6723
# Epoch 128/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6128 - accuracy: 0.6713
# Epoch 129/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6128 - accuracy: 0.6725
# Epoch 130/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6135 - accuracy: 0.6692
# Epoch 131/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6128 - accuracy: 0.6720
# Epoch 132/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6122 - accuracy: 0.6709
# Epoch 133/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6128 - accuracy: 0.6716
# Epoch 134/150
# 2313/2313 [==============================] - 1s 524us/step - loss: 0.6132 - accuracy: 0.6707
# Epoch 135/150
# 2313/2313 [==============================] - 1s 481us/step - loss: 0.6132 - accuracy: 0.6697
# Epoch 136/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6127 - accuracy: 0.6713
# Epoch 137/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6130 - accuracy: 0.6711
# Epoch 138/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6126 - accuracy: 0.6701
# Epoch 139/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6131 - accuracy: 0.6721
# Epoch 140/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6128 - accuracy: 0.6715
# Epoch 141/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6122 - accuracy: 0.6735
# Epoch 142/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6129 - accuracy: 0.6696
# Epoch 143/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6124 - accuracy: 0.6719
# Epoch 144/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6121 - accuracy: 0.6700
# Epoch 145/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6127 - accuracy: 0.6720
# Epoch 146/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6123 - accuracy: 0.6697
# Epoch 147/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6115 - accuracy: 0.6735
# Epoch 148/150
# 2313/2313 [==============================] - 1s 479us/step - loss: 0.6120 - accuracy: 0.6703
# Epoch 149/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6111 - accuracy: 0.6716
# Epoch 150/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6134 - accuracy: 0.6719
# Epoch 1/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.8205 - accuracy: 0.5581
# Epoch 2/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6910 - accuracy: 0.5830
# Epoch 3/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6745 - accuracy: 0.5927
# Epoch 4/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6677 - accuracy: 0.5928
# Epoch 5/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6664 - accuracy: 0.5914
# Epoch 6/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6632 - accuracy: 0.6035
# Epoch 7/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6646 - accuracy: 0.6029
# Epoch 8/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6621 - accuracy: 0.6079
# Epoch 9/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6574 - accuracy: 0.6116
# Epoch 10/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6546 - accuracy: 0.6187
# Epoch 11/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6455 - accuracy: 0.6317
# Epoch 12/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6413 - accuracy: 0.6393
# Epoch 13/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6416 - accuracy: 0.6403
# Epoch 14/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6407 - accuracy: 0.6407
# Epoch 15/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6415 - accuracy: 0.6400
# Epoch 16/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6381 - accuracy: 0.6475
# Epoch 17/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6395 - accuracy: 0.6453
# Epoch 18/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6384 - accuracy: 0.6453
# Epoch 19/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6376 - accuracy: 0.6492
# Epoch 20/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6378 - accuracy: 0.6476
# Epoch 21/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6379 - accuracy: 0.6486
# Epoch 22/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6368 - accuracy: 0.6484
# Epoch 23/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6364 - accuracy: 0.6476
# Epoch 24/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6377 - accuracy: 0.6466
# Epoch 25/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6363 - accuracy: 0.6505
# Epoch 26/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6355 - accuracy: 0.6502
# Epoch 27/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6365 - accuracy: 0.6492
# Epoch 28/150
# 2313/2313 [==============================] - 1s 486us/step - loss: 0.6354 - accuracy: 0.6524
# Epoch 29/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6358 - accuracy: 0.6501
# Epoch 30/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6354 - accuracy: 0.6503
# Epoch 31/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6355 - accuracy: 0.6496
# Epoch 32/150
# 2313/2313 [==============================] - 1s 466us/step - loss: 0.6359 - accuracy: 0.6492
# Epoch 33/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6350 - accuracy: 0.6501
# Epoch 34/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6344 - accuracy: 0.6516
# Epoch 35/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6349 - accuracy: 0.6516
# Epoch 36/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6337 - accuracy: 0.6520
# Epoch 37/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6340 - accuracy: 0.6529
# Epoch 38/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6342 - accuracy: 0.6526
# Epoch 39/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6335 - accuracy: 0.6526
# Epoch 40/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6364 - accuracy: 0.6496
# Epoch 41/150
# 2313/2313 [==============================] - 1s 451us/step - loss: 0.6331 - accuracy: 0.6532
# Epoch 42/150
# 2313/2313 [==============================] - 1s 460us/step - loss: 0.6336 - accuracy: 0.6520
# Epoch 43/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6347 - accuracy: 0.6499
# Epoch 44/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6324 - accuracy: 0.6539
# Epoch 45/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6336 - accuracy: 0.6507
# Epoch 46/150
# 2313/2313 [==============================] - 1s 466us/step - loss: 0.6330 - accuracy: 0.6513
# Epoch 47/150
# 2313/2313 [==============================] - 1s 463us/step - loss: 0.6313 - accuracy: 0.6549
# Epoch 48/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6329 - accuracy: 0.6500
# Epoch 49/150
# 2313/2313 [==============================] - 1s 456us/step - loss: 0.6336 - accuracy: 0.6529
# Epoch 50/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6321 - accuracy: 0.6524
# Epoch 51/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6332 - accuracy: 0.6500
# Epoch 52/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6325 - accuracy: 0.6492
# Epoch 53/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6315 - accuracy: 0.6527
# Epoch 54/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6318 - accuracy: 0.6496
# Epoch 55/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6299 - accuracy: 0.6530
# Epoch 56/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6302 - accuracy: 0.6549
# Epoch 57/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6294 - accuracy: 0.6554
# Epoch 58/150
# 2313/2313 [==============================] - 1s 455us/step - loss: 0.6288 - accuracy: 0.6571
# Epoch 59/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6302 - accuracy: 0.6544
# Epoch 60/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6299 - accuracy: 0.6542
# Epoch 61/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6310 - accuracy: 0.6513
# Epoch 62/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6292 - accuracy: 0.6546
# Epoch 63/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6273 - accuracy: 0.6563
# Epoch 64/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6292 - accuracy: 0.6530
# Epoch 65/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6277 - accuracy: 0.6580
# Epoch 66/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6283 - accuracy: 0.6546
# Epoch 67/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6287 - accuracy: 0.6549
# Epoch 68/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6281 - accuracy: 0.6575
# Epoch 69/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6287 - accuracy: 0.6555
# Epoch 70/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6277 - accuracy: 0.6576
# Epoch 71/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6284 - accuracy: 0.6553
# Epoch 72/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6276 - accuracy: 0.6588
# Epoch 73/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6262 - accuracy: 0.6606
# Epoch 74/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6277 - accuracy: 0.6580
# Epoch 75/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6273 - accuracy: 0.6578
# Epoch 76/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6259 - accuracy: 0.6610
# Epoch 77/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6296 - accuracy: 0.6582
# Epoch 78/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6264 - accuracy: 0.6598
# Epoch 79/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6275 - accuracy: 0.6594
# Epoch 80/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6249 - accuracy: 0.6639
# Epoch 81/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6262 - accuracy: 0.6565
# Epoch 82/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6261 - accuracy: 0.6605
# Epoch 83/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6265 - accuracy: 0.6610
# Epoch 84/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6280 - accuracy: 0.6538
# Epoch 85/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6255 - accuracy: 0.6620
# Epoch 86/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6240 - accuracy: 0.6627
# Epoch 87/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6234 - accuracy: 0.6662
# Epoch 88/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6244 - accuracy: 0.6630
# Epoch 89/150
# 2313/2313 [==============================] - 1s 461us/step - loss: 0.6239 - accuracy: 0.6652
# Epoch 90/150
# 2313/2313 [==============================] - 1s 456us/step - loss: 0.6236 - accuracy: 0.6640
# Epoch 91/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6228 - accuracy: 0.6646
# Epoch 92/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6403 - accuracy: 0.6376
# Epoch 93/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6258 - accuracy: 0.6600
# Epoch 94/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6270 - accuracy: 0.6589
# Epoch 95/150
# 2313/2313 [==============================] - 1s 469us/step - loss: 0.6236 - accuracy: 0.6629
# Epoch 96/150
# 2313/2313 [==============================] - 1s 499us/step - loss: 0.6224 - accuracy: 0.6637
# Epoch 97/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6250 - accuracy: 0.6624
# Epoch 98/150
# 2313/2313 [==============================] - 1s 440us/step - loss: 0.6224 - accuracy: 0.6666
# Epoch 99/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6233 - accuracy: 0.6652
# Epoch 100/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6289 - accuracy: 0.6581
# Epoch 101/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6221 - accuracy: 0.6658
# Epoch 102/150
# 2313/2313 [==============================] - 1s 458us/step - loss: 0.6266 - accuracy: 0.6595
# Epoch 103/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6240 - accuracy: 0.6613
# Epoch 104/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6218 - accuracy: 0.6659
# Epoch 105/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6219 - accuracy: 0.6666
# Epoch 106/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6212 - accuracy: 0.6677
# Epoch 107/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6214 - accuracy: 0.6664
# Epoch 108/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6195 - accuracy: 0.6700
# Epoch 109/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6249 - accuracy: 0.6603
# Epoch 110/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6201 - accuracy: 0.6697
# Epoch 111/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6215 - accuracy: 0.6647
# Epoch 112/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6226 - accuracy: 0.6620
# Epoch 113/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6203 - accuracy: 0.6693
# Epoch 114/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6216 - accuracy: 0.6638
# Epoch 115/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6198 - accuracy: 0.6692
# Epoch 116/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6204 - accuracy: 0.6674
# Epoch 117/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6228 - accuracy: 0.6666
# Epoch 118/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6196 - accuracy: 0.6696
# Epoch 119/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6204 - accuracy: 0.6658
# Epoch 120/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6235 - accuracy: 0.6656
# Epoch 121/150
# 2313/2313 [==============================] - 1s 476us/step - loss: 0.6209 - accuracy: 0.6679
# Epoch 122/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6205 - accuracy: 0.6663
# Epoch 123/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6203 - accuracy: 0.6643
# Epoch 124/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6207 - accuracy: 0.6685
# Epoch 125/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6199 - accuracy: 0.6676
# Epoch 126/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6191 - accuracy: 0.6694
# Epoch 127/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6194 - accuracy: 0.6710
# Epoch 128/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6199 - accuracy: 0.6694
# Epoch 129/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6197 - accuracy: 0.6679
# Epoch 130/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6216 - accuracy: 0.6633
# Epoch 131/150
# 2313/2313 [==============================] - 1s 451us/step - loss: 0.6207 - accuracy: 0.6676
# Epoch 132/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6226 - accuracy: 0.6638
# Epoch 133/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6197 - accuracy: 0.6696
# Epoch 134/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6191 - accuracy: 0.6697
# Epoch 135/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6201 - accuracy: 0.6657
# Epoch 136/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6202 - accuracy: 0.6671
# Epoch 137/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6195 - accuracy: 0.6665
# Epoch 138/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6193 - accuracy: 0.6697
# Epoch 139/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6184 - accuracy: 0.6725
# Epoch 140/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6185 - accuracy: 0.6704
# Epoch 141/150
# 2313/2313 [==============================] - 1s 535us/step - loss: 0.6182 - accuracy: 0.6713
# Epoch 142/150
# 2313/2313 [==============================] - 1s 552us/step - loss: 0.6189 - accuracy: 0.6700
# Epoch 143/150
# 2313/2313 [==============================] - 1s 459us/step - loss: 0.6183 - accuracy: 0.6717
# Epoch 144/150
# 2313/2313 [==============================] - 1s 517us/step - loss: 0.6188 - accuracy: 0.6708
# Epoch 145/150
# 2313/2313 [==============================] - 1s 473us/step - loss: 0.6187 - accuracy: 0.6700
# Epoch 146/150
# 2313/2313 [==============================] - 1s 539us/step - loss: 0.6213 - accuracy: 0.6607
# Epoch 147/150
# 2313/2313 [==============================] - 1s 514us/step - loss: 0.6187 - accuracy: 0.6697
# Epoch 148/150
# 2313/2313 [==============================] - 1s 483us/step - loss: 0.6195 - accuracy: 0.6666
# Epoch 149/150
# 2313/2313 [==============================] - 1s 508us/step - loss: 0.6176 - accuracy: 0.6724
# Epoch 150/150
# 2313/2313 [==============================] - 1s 511us/step - loss: 0.6170 - accuracy: 0.6734
# Epoch 1/150
# 2313/2313 [==============================] - 1s 469us/step - loss: 0.8958 - accuracy: 0.5273
# Epoch 2/150
# 2313/2313 [==============================] - 1s 460us/step - loss: 0.6866 - accuracy: 0.5563
# Epoch 3/150
# 2313/2313 [==============================] - 1s 458us/step - loss: 0.6858 - accuracy: 0.5597
# Epoch 4/150
# 2313/2313 [==============================] - 1s 564us/step - loss: 0.6853 - accuracy: 0.5620
# Epoch 5/150
# 2313/2313 [==============================] - 1s 459us/step - loss: 0.6795 - accuracy: 0.5687
# Epoch 6/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6753 - accuracy: 0.5765
# Epoch 7/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6720 - accuracy: 0.5834
# Epoch 8/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6678 - accuracy: 0.5955
# Epoch 9/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6629 - accuracy: 0.6037
# Epoch 10/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6592 - accuracy: 0.6111
# Epoch 11/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6531 - accuracy: 0.6206
# Epoch 12/150
# 2313/2313 [==============================] - 1s 449us/step - loss: 0.6486 - accuracy: 0.6280
# Epoch 13/150
# 2313/2313 [==============================] - 1s 460us/step - loss: 0.6420 - accuracy: 0.6393
# Epoch 14/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6397 - accuracy: 0.6430
# Epoch 15/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6392 - accuracy: 0.6435
# Epoch 16/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6364 - accuracy: 0.6452
# Epoch 17/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6363 - accuracy: 0.6444
# Epoch 18/150
# 2313/2313 [==============================] - 1s 476us/step - loss: 0.6360 - accuracy: 0.6475
# Epoch 19/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6349 - accuracy: 0.6475
# Epoch 20/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6342 - accuracy: 0.6471
# Epoch 21/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6336 - accuracy: 0.6489
# Epoch 22/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6340 - accuracy: 0.6489
# Epoch 23/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6330 - accuracy: 0.6453
# Epoch 24/150
# 2313/2313 [==============================] - 1s 458us/step - loss: 0.6324 - accuracy: 0.6490
# Epoch 25/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6323 - accuracy: 0.6507
# Epoch 26/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6321 - accuracy: 0.6514
# Epoch 27/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6317 - accuracy: 0.6504
# Epoch 28/150
# 2313/2313 [==============================] - 1s 451us/step - loss: 0.6318 - accuracy: 0.6500
# Epoch 29/150
# 2313/2313 [==============================] - 1s 480us/step - loss: 0.6316 - accuracy: 0.6495
# Epoch 30/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6297 - accuracy: 0.6529
# Epoch 31/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6310 - accuracy: 0.6508
# Epoch 32/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6309 - accuracy: 0.6527
# Epoch 33/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6305 - accuracy: 0.6524
# Epoch 34/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6302 - accuracy: 0.6544
# Epoch 35/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6299 - accuracy: 0.6523
# Epoch 36/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6302 - accuracy: 0.6531
# Epoch 37/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6299 - accuracy: 0.6514
# Epoch 38/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6295 - accuracy: 0.6533
# Epoch 39/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6287 - accuracy: 0.6527
# Epoch 40/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6291 - accuracy: 0.6537
# Epoch 41/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6290 - accuracy: 0.6523
# Epoch 42/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6293 - accuracy: 0.6525
# Epoch 43/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6280 - accuracy: 0.6547
# Epoch 44/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6279 - accuracy: 0.6526
# Epoch 45/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6282 - accuracy: 0.6538
# Epoch 46/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6281 - accuracy: 0.6513
# Epoch 47/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6264 - accuracy: 0.6547
# Epoch 48/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6275 - accuracy: 0.6532
# Epoch 49/150
# 2313/2313 [==============================] - 1s 468us/step - loss: 0.6269 - accuracy: 0.6534
# Epoch 50/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6265 - accuracy: 0.6544
# Epoch 51/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6265 - accuracy: 0.6552
# Epoch 52/150
# 2313/2313 [==============================] - 1s 440us/step - loss: 0.6264 - accuracy: 0.6543
# Epoch 53/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6279 - accuracy: 0.6559
# Epoch 54/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6263 - accuracy: 0.6559
# Epoch 55/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6265 - accuracy: 0.6551
# Epoch 56/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6266 - accuracy: 0.6558
# Epoch 57/150
# 2313/2313 [==============================] - 1s 459us/step - loss: 0.6264 - accuracy: 0.6548
# Epoch 58/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6258 - accuracy: 0.6548
# Epoch 59/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6250 - accuracy: 0.6579
# Epoch 60/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6256 - accuracy: 0.6582
# Epoch 61/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6253 - accuracy: 0.6579
# Epoch 62/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6253 - accuracy: 0.6569
# Epoch 63/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6258 - accuracy: 0.6546
# Epoch 64/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6248 - accuracy: 0.6554
# Epoch 65/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6246 - accuracy: 0.6574
# Epoch 66/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6242 - accuracy: 0.6563
# Epoch 67/150
# 2313/2313 [==============================] - 1s 469us/step - loss: 0.6244 - accuracy: 0.6572
# Epoch 68/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6242 - accuracy: 0.6578
# Epoch 69/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6237 - accuracy: 0.6558
# Epoch 70/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6234 - accuracy: 0.6580
# Epoch 71/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6236 - accuracy: 0.6578
# Epoch 72/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6242 - accuracy: 0.6569
# Epoch 73/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6241 - accuracy: 0.6574
# Epoch 74/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6235 - accuracy: 0.6589
# Epoch 75/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6233 - accuracy: 0.6602
# Epoch 76/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6223 - accuracy: 0.6599
# Epoch 77/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6225 - accuracy: 0.6605
# Epoch 78/150
# 2313/2313 [==============================] - 1s 449us/step - loss: 0.6225 - accuracy: 0.6599
# Epoch 79/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6224 - accuracy: 0.6594
# Epoch 80/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6214 - accuracy: 0.6619
# Epoch 81/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6208 - accuracy: 0.6636
# Epoch 82/150
# 2313/2313 [==============================] - 1s 472us/step - loss: 0.6210 - accuracy: 0.6636
# Epoch 83/150
# 2313/2313 [==============================] - 1s 526us/step - loss: 0.6212 - accuracy: 0.6630
# Epoch 84/150
# 2313/2313 [==============================] - 1s 557us/step - loss: 0.6204 - accuracy: 0.6646
# Epoch 85/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6193 - accuracy: 0.6661
# Epoch 86/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6201 - accuracy: 0.6642
# Epoch 87/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6188 - accuracy: 0.6669
# Epoch 88/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6187 - accuracy: 0.6663
# Epoch 89/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6179 - accuracy: 0.6692
# Epoch 90/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6187 - accuracy: 0.6671
# Epoch 91/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6183 - accuracy: 0.6656
# Epoch 92/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6188 - accuracy: 0.6667
# Epoch 93/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6172 - accuracy: 0.6686
# Epoch 94/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6184 - accuracy: 0.6672
# Epoch 95/150
# 2313/2313 [==============================] - 1s 440us/step - loss: 0.6186 - accuracy: 0.6670
# Epoch 96/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6174 - accuracy: 0.6695
# Epoch 97/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6174 - accuracy: 0.6687
# Epoch 98/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6172 - accuracy: 0.6692
# Epoch 99/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6177 - accuracy: 0.6702
# Epoch 100/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6169 - accuracy: 0.6690
# Epoch 101/150
# 2313/2313 [==============================] - 1s 449us/step - loss: 0.6174 - accuracy: 0.6705
# Epoch 102/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6161 - accuracy: 0.6730
# Epoch 103/150
# 2313/2313 [==============================] - 1s 461us/step - loss: 0.6173 - accuracy: 0.6690
# Epoch 104/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6166 - accuracy: 0.6671
# Epoch 105/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6184 - accuracy: 0.6682
# Epoch 106/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6165 - accuracy: 0.6689
# Epoch 107/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6160 - accuracy: 0.6714
# Epoch 108/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6181 - accuracy: 0.6667
# Epoch 109/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6167 - accuracy: 0.6695
# Epoch 110/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6155 - accuracy: 0.6698
# Epoch 111/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6155 - accuracy: 0.6714
# Epoch 112/150
# 2313/2313 [==============================] - 1s 483us/step - loss: 0.6151 - accuracy: 0.6721
# Epoch 113/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6156 - accuracy: 0.6706
# Epoch 114/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6162 - accuracy: 0.6710
# Epoch 115/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6163 - accuracy: 0.6679
# Epoch 116/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6153 - accuracy: 0.6716
# Epoch 117/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6147 - accuracy: 0.6707
# Epoch 118/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6144 - accuracy: 0.6727
# Epoch 119/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6188 - accuracy: 0.6670
# Epoch 120/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6160 - accuracy: 0.6686
# Epoch 121/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6156 - accuracy: 0.6677
# Epoch 122/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6166 - accuracy: 0.6703
# Epoch 123/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6150 - accuracy: 0.6715
# Epoch 124/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6172 - accuracy: 0.6676
# Epoch 125/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6145 - accuracy: 0.6705
# Epoch 126/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6159 - accuracy: 0.6700
# Epoch 127/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6143 - accuracy: 0.6734
# Epoch 128/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6161 - accuracy: 0.6690
# Epoch 129/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6153 - accuracy: 0.6700
# Epoch 130/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6142 - accuracy: 0.6719
# Epoch 131/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6133 - accuracy: 0.6741
# Epoch 132/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6146 - accuracy: 0.6715
# Epoch 133/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6146 - accuracy: 0.6712
# Epoch 134/150
# ...
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.7652 - accuracy: 0.5495
# Epoch 2/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6860 - accuracy: 0.5582
# Epoch 3/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6705 - accuracy: 0.5888
# Epoch 4/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6656 - accuracy: 0.5929
# Epoch 5/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6635 - accuracy: 0.5979
# Epoch 6/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6627 - accuracy: 0.5975
# Epoch 7/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6617 - accuracy: 0.5997
# Epoch 8/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6614 - accuracy: 0.5999
# Epoch 9/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6609 - accuracy: 0.6007
# Epoch 10/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6592 - accuracy: 0.6029
# Epoch 11/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6605 - accuracy: 0.6001
# Epoch 12/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6590 - accuracy: 0.6026
# Epoch 13/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6592 - accuracy: 0.6037
# Epoch 14/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6574 - accuracy: 0.6057
# Epoch 15/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6536 - accuracy: 0.6130
# Epoch 16/150
# 2313/2313 [==============================] - 1s 447us/step - loss: 0.6371 - accuracy: 0.6475
# Epoch 17/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6342 - accuracy: 0.6537
# Epoch 18/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6340 - accuracy: 0.6546
# Epoch 19/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6342 - accuracy: 0.6542
# Epoch 20/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6330 - accuracy: 0.6561
# Epoch 21/150
# 2313/2313 [==============================] - 1s 479us/step - loss: 0.6326 - accuracy: 0.6554
# Epoch 22/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6331 - accuracy: 0.6568
# Epoch 23/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6332 - accuracy: 0.6557
# Epoch 24/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6329 - accuracy: 0.6570
# Epoch 25/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6318 - accuracy: 0.6577
# Epoch 26/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6316 - accuracy: 0.6574
# Epoch 27/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6332 - accuracy: 0.6555
# Epoch 28/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6329 - accuracy: 0.6554
# Epoch 29/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6323 - accuracy: 0.6560
# Epoch 30/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6342 - accuracy: 0.6519
# Epoch 31/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6320 - accuracy: 0.6571
# Epoch 32/150
# 2313/2313 [==============================] - 1s 451us/step - loss: 0.6324 - accuracy: 0.6562
# Epoch 33/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6335 - accuracy: 0.6541
# Epoch 34/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6327 - accuracy: 0.6574
# Epoch 35/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6317 - accuracy: 0.6570
# Epoch 36/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6321 - accuracy: 0.6566
# Epoch 37/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6311 - accuracy: 0.6582
# Epoch 38/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6309 - accuracy: 0.6582
# Epoch 39/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6310 - accuracy: 0.6592
# Epoch 40/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6320 - accuracy: 0.6566
# Epoch 41/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6313 - accuracy: 0.6587
# Epoch 42/150
# 2313/2313 [==============================] - 1s 455us/step - loss: 0.6320 - accuracy: 0.6568
# Epoch 43/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6305 - accuracy: 0.6594
# Epoch 44/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6309 - accuracy: 0.6595
# Epoch 45/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6315 - accuracy: 0.6571
# Epoch 46/150
# 2313/2313 [==============================] - 1s 461us/step - loss: 0.6294 - accuracy: 0.6609
# Epoch 47/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6288 - accuracy: 0.6626
# Epoch 48/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6331 - accuracy: 0.6551
# Epoch 49/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6312 - accuracy: 0.6582
# Epoch 50/150
# 2313/2313 [==============================] - 1s 545us/step - loss: 0.6315 - accuracy: 0.6574
# Epoch 51/150
# 2313/2313 [==============================] - 1s 502us/step - loss: 0.6285 - accuracy: 0.6618
# Epoch 52/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6301 - accuracy: 0.6590
# Epoch 53/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6292 - accuracy: 0.6621
# Epoch 54/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6294 - accuracy: 0.6600
# Epoch 55/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6315 - accuracy: 0.6553
# Epoch 56/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6288 - accuracy: 0.6608
# Epoch 57/150
# 2313/2313 [==============================] - 1s 450us/step - loss: 0.6332 - accuracy: 0.6569
# Epoch 58/150
# 2313/2313 [==============================] - 1s 438us/step - loss: 0.6298 - accuracy: 0.6608
# Epoch 59/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6307 - accuracy: 0.6575
# Epoch 60/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6292 - accuracy: 0.6615
# Epoch 61/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6301 - accuracy: 0.6587
# Epoch 62/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6309 - accuracy: 0.6592
# Epoch 63/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6283 - accuracy: 0.6624
# Epoch 64/150
# 2313/2313 [==============================] - 1s 452us/step - loss: 0.6283 - accuracy: 0.6631
# Epoch 65/150
# 2313/2313 [==============================] - 1s 463us/step - loss: 0.6292 - accuracy: 0.6614
# Epoch 66/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6281 - accuracy: 0.6623
# Epoch 67/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6338 - accuracy: 0.6507
# Epoch 68/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6327 - accuracy: 0.6573
# Epoch 69/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6305 - accuracy: 0.6600
# Epoch 70/150
# 2313/2313 [==============================] - 1s 454us/step - loss: 0.6301 - accuracy: 0.6595
# Epoch 71/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6294 - accuracy: 0.6620
# Epoch 72/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6296 - accuracy: 0.6622
# Epoch 73/150
# 2313/2313 [==============================] - 1s 428us/step - loss: 0.6303 - accuracy: 0.6597
# Epoch 74/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6295 - accuracy: 0.6603
# Epoch 75/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6292 - accuracy: 0.6620
# Epoch 76/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6287 - accuracy: 0.6631
# Epoch 77/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6286 - accuracy: 0.6636
# Epoch 78/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6291 - accuracy: 0.6613
# Epoch 79/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6306 - accuracy: 0.6592
# Epoch 80/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6301 - accuracy: 0.6614
# Epoch 81/150
# 2313/2313 [==============================] - 1s 440us/step - loss: 0.6304 - accuracy: 0.6605
# Epoch 82/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6286 - accuracy: 0.6625
# Epoch 83/150
# 2313/2313 [==============================] - 1s 440us/step - loss: 0.6286 - accuracy: 0.6630
# Epoch 84/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6284 - accuracy: 0.6639
# Epoch 85/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6282 - accuracy: 0.6626
# Epoch 86/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6279 - accuracy: 0.6637
# Epoch 87/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6289 - accuracy: 0.6613
# Epoch 88/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6276 - accuracy: 0.6648
# Epoch 89/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6282 - accuracy: 0.6638
# Epoch 90/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6272 - accuracy: 0.6644
# Epoch 91/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6284 - accuracy: 0.6616
# Epoch 92/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6320 - accuracy: 0.6571
# Epoch 93/150
# 2313/2313 [==============================] - 1s 467us/step - loss: 0.6280 - accuracy: 0.6640
# Epoch 94/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6284 - accuracy: 0.6638
# Epoch 95/150
# 2313/2313 [==============================] - 1s 429us/step - loss: 0.6280 - accuracy: 0.6621
# Epoch 96/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6285 - accuracy: 0.6621
# Epoch 97/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6287 - accuracy: 0.6620
# Epoch 98/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6281 - accuracy: 0.6647
# Epoch 99/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6277 - accuracy: 0.6644
# Epoch 100/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6283 - accuracy: 0.6636
# Epoch 101/150
# 2313/2313 [==============================] - 1s 459us/step - loss: 0.6297 - accuracy: 0.6614
# Epoch 102/150
# 2313/2313 [==============================] - 1s 427us/step - loss: 0.6279 - accuracy: 0.6648
# Epoch 103/150
# 2313/2313 [==============================] - 1s 482us/step - loss: 0.6272 - accuracy: 0.6656
# Epoch 104/150
# 2313/2313 [==============================] - 1s 473us/step - loss: 0.6305 - accuracy: 0.6598
# Epoch 105/150
# 2313/2313 [==============================] - 1s 555us/step - loss: 0.6278 - accuracy: 0.6636
# Epoch 106/150
# 2313/2313 [==============================] - 1s 439us/step - loss: 0.6276 - accuracy: 0.6644
# Epoch 107/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6306 - accuracy: 0.6589
# Epoch 108/150
# 2313/2313 [==============================] - 1s 434us/step - loss: 0.6266 - accuracy: 0.6655
# Epoch 109/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6271 - accuracy: 0.6646
# Epoch 110/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6271 - accuracy: 0.6649
# Epoch 111/150
# 2313/2313 [==============================] - 1s 441us/step - loss: 0.6275 - accuracy: 0.6639
# Epoch 112/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6268 - accuracy: 0.6650
# Epoch 113/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6263 - accuracy: 0.6664
# Epoch 114/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6271 - accuracy: 0.6646
# Epoch 115/150
# 2313/2313 [==============================] - 1s 568us/step - loss: 0.6270 - accuracy: 0.6650
# Epoch 116/150
# 2313/2313 [==============================] - 1s 527us/step - loss: 0.6274 - accuracy: 0.6645
# Epoch 117/150
# 2313/2313 [==============================] - 1s 475us/step - loss: 0.6263 - accuracy: 0.6666
# Epoch 118/150
# 2313/2313 [==============================] - 1s 508us/step - loss: 0.6272 - accuracy: 0.6645
# Epoch 119/150
# 2313/2313 [==============================] - 1s 480us/step - loss: 0.6271 - accuracy: 0.6656
# Epoch 120/150
# 2313/2313 [==============================] - 1s 448us/step - loss: 0.6281 - accuracy: 0.6637
# Epoch 121/150
# 2313/2313 [==============================] - 1s 473us/step - loss: 0.6282 - accuracy: 0.6625
# Epoch 122/150
# 2313/2313 [==============================] - 1s 478us/step - loss: 0.6274 - accuracy: 0.6646
# Epoch 123/150
# 2313/2313 [==============================] - 1s 451us/step - loss: 0.6288 - accuracy: 0.6624
# Epoch 124/150
# 2313/2313 [==============================] - 1s 468us/step - loss: 0.6275 - accuracy: 0.6642
# Epoch 125/150
# 2313/2313 [==============================] - 1s 488us/step - loss: 0.6282 - accuracy: 0.6636
# Epoch 126/150
# 2313/2313 [==============================] - 1s 444us/step - loss: 0.6282 - accuracy: 0.6616
# Epoch 127/150
# 2313/2313 [==============================] - 1s 432us/step - loss: 0.6257 - accuracy: 0.6677
# Epoch 128/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6290 - accuracy: 0.6627
# Epoch 129/150
# 2313/2313 [==============================] - 1s 480us/step - loss: 0.6351 - accuracy: 0.6466
# Epoch 130/150
# 2313/2313 [==============================] - 1s 491us/step - loss: 0.6264 - accuracy: 0.6643
# Epoch 131/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6268 - accuracy: 0.6650
# Epoch 132/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6301 - accuracy: 0.6595
# Epoch 133/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6270 - accuracy: 0.6643
# Epoch 134/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6269 - accuracy: 0.6662
# Epoch 135/150
# 2313/2313 [==============================] - 1s 435us/step - loss: 0.6279 - accuracy: 0.6629
# Epoch 136/150
# 2313/2313 [==============================] - 1s 446us/step - loss: 0.6273 - accuracy: 0.6650
# Epoch 137/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6269 - accuracy: 0.6650
# Epoch 138/150
# 2313/2313 [==============================] - 1s 453us/step - loss: 0.6256 - accuracy: 0.6677
# Epoch 139/150
# 2313/2313 [==============================] - 1s 476us/step - loss: 0.6281 - accuracy: 0.6630
# Epoch 140/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6278 - accuracy: 0.6636
# Epoch 141/150
# 2313/2313 [==============================] - 1s 431us/step - loss: 0.6275 - accuracy: 0.6638
# Epoch 142/150
# 2313/2313 [==============================] - 1s 433us/step - loss: 0.6269 - accuracy: 0.6649
# Epoch 143/150
# 2313/2313 [==============================] - 1s 436us/step - loss: 0.6259 - accuracy: 0.6660
# Epoch 144/150
# 2313/2313 [==============================] - 1s 500us/step - loss: 0.6260 - accuracy: 0.6664
# Epoch 145/150
# 2313/2313 [==============================] - 1s 445us/step - loss: 0.6284 - accuracy: 0.6637
# Epoch 146/150
# 2313/2313 [==============================] - 1s 443us/step - loss: 0.6262 - accuracy: 0.6666
# Epoch 147/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6253 - accuracy: 0.6666
# Epoch 148/150
# 2313/2313 [==============================] - 1s 442us/step - loss: 0.6257 - accuracy: 0.6669
# Epoch 149/150
# 2313/2313 [==============================] - 1s 430us/step - loss: 0.6266 - accuracy: 0.6658
# Epoch 150/150
# 2313/2313 [==============================] - 1s 437us/step - loss: 0.6262 - accuracy: 0.6666
# Neural Network model -> media: -0.626848 varianza: 0.025067

# %% [markdown]
# El resultado de cada modelo, por orden descendente de negative log loss es:
#
#     - XGBOOST -> media  neg log loss: -0.626136, varianza: 0.013309
#     - Red neuronal  ->  media  neg log loss: -0.626848, varianza: 0.025067.
#     - SVC -> media   neg log loss: -0.668714, varianza: 0.006722.
#     - RandomForest -> media  neg log  loss:  -0.673417, varianza: 0.024723.
#     - Adaboost -> media neg log loss: -0.688801, varianza: 0.000467.
#     - KNN -> media neg log loss: -1.986807, varianza: 0.116187.
#
# Elijo como mejor modelo XGBoost, ya que es el que tiene mayor negative log loss.

# %% [markdown]
# Para crear el dataframe antes mencionado con el valor de negative log loss por cada iteración de cross_val_score, junto con información del modelo al que pertenece, creo un diccionario donde guardo el contenido de las listas antes mencionadas destinadas a crear el dataframe:

# %%
dic_cv = {} #Creo un diccionario

#Donde guardo el contenido de las listas antes mencionadas destinadas a crear el dataframe:

dic_cv['modelos'] = modeldf 
dic_cv['neg_log_loss'] = neg_loglossdf

# %% [markdown]
# El diccionario creado lo transformo en el dataframe:

# %%
cv_df = pd.DataFrame.from_dict(dic_cv)

# %% [markdown]
# Y lo guardo como csv para guardar de manera más "sólida" los resultados de cross_val_score, y así poder usarlo en un proceso posterior de visualización:

# %%
cv_df.to_csv('resultados_cv.csv', index=False)
